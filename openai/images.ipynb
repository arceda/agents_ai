# %%
from openai import OpenAI
from dotenv import load_dotenv, find_dotenv
from pathlib import Path
import os

# en windows es necesario especificar la ruta del .env
load_dotenv()
client = OpenAI(api_key=os.environ.get("OPENAI_API_KEY"))

# %% [markdown]
# # Dall-e-3

# %% [markdown]
# Solo permite la creación de imágenes

# %%
# Soporta tamaños de: 1024x1024, 1792x1024, or 1024x1792 para dall-e-3
# Quality: hd, statandar. Solo en dall-e-3
# response_format: url, b64_json, el url solo esta disponible por una hora
# response_format

from openai import OpenAI
client = OpenAI()

response = client.images.generate(
    model="dall-e-3",
    prompt="An avatar for an expert in Data Analysis",
    size="1024x1024",
    quality="standard",
    response_format="url",
    n=1, # numero de imagenes a generar
)

print(response.data[0].url)
print(response.data)
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-VOafWYZ7TCoxMw0Wr7yg0Av4/user-P90AMMWkhQIZK9ejaJph3C6A/img-vbcXbdhn3ujzaQ5VbRru11QM.png?st=2024-12-21T15%3A40%3A39Z&se=2024-12-21T17%3A40%3A39Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-12-20T19%3A24%3A51Z&ske=2024-12-21T19%3A24%3A51Z&sks=b&skv=2024-08-04&sig=EPbZC7EkogM4dfitEhdI1y4Ok14gNhCov/cpHRwPv4o%3D
# ...

# %% [markdown]
# Imagen en Base64_json

# %%
prompt = """
You must generate an avatar with these features:

# Features
## Background: Always use a white background
## Body: Show the entire body of the avatar gazing you
## Light: Soft and bright
## Colors: Use vivid color following best practices for disigning
## Shadows: AVOID using sadhows
## Apparel: Include additional accesories according to the avatar's description
## Position: Only draw one avatar in the middle of the image

# Avatar description

"""

# %%
# Soporta tamaños de: 1024x1024, 1792x1024, or 1024x1792 para dall-e-3
# Quality: hd, statandar. Solo en dall-e-3
# response_format: url, b64_json
# response_format

from openai import OpenAI
client = OpenAI()

response = client.images.generate(
    model="dall-e-3",
    prompt=prompt + "An avatar for an expert in Data Analysis",
    size="1024x1024",
    quality="standard",
    response_format="b64_json",
    n=1, # numero de imagenes a generar
)

print(response.data)
# Out:
# [Image(b64_json='...', revised_prompt="Create a full-length avatar illustration. The background should be transparent. The figure should be portrayed looking at the viewer with a soft and bright light illuminating them. The colors should be vibrant, adhering to recognized design practices. Shadows should be minimized. The avatar is an expert in data analysis and should have appropriate accessories such as a laptop computer, a pair of glasses, a statistical chart, and perhaps a pen in hand or a pocket protector full of pens. The avatar's gender and race should not be readily discernible to promote character inclusivity.", url=None)]

# %%
import base64

# Supongamos que `response` es el resultado de la llamada a OpenAI API
b64_image = response.data[0].b64_json  # Extrae el contenido base64 de la respuesta

# Decodifica el contenido base64
image_data = base64.b64decode(b64_image)

# Guarda la imagen en un archivo
with open("avatar.png", "wb") as image_file:
    image_file.write(image_data)

print("avatar.png")
# Out:
# avatar.png

# %% [markdown]
# # Dall-e-2

# %% [markdown]
# Permite crear y editar imágenes
